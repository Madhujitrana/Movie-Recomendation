# %% [markdown]
# # Movie Recommendation using

# %%
import difflib
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df=pd.read_csv(r"C:\Users\Madhujit\Desktop\pr report\netflix_titles.csv")

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df=df.fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                      Unknown
# 2                      Unknown
# ...

# %%
selected_feature=df[["title","director","cast","listed_in"]]

# %%
combine_feature=df["title"]+' '+df["director"]+' '+df["cast"]+' '+df["listed_in"]

# %%
combine_feature
# Out:
# 0       Norm of the North: King Sized Adventure Richar...
# 1       Jandino: Whatever it Takes Unknown Jandino Asp...
# 2       Transformers Prime Unknown Peter Cullen, Sumal...
# 3       Transformers: Robots in Disguise Unknown Will ...
# 4       #realityhigh Fernando Lebrija Nesta Cooper, Ka...
#                               ...
# 6229    Red vs. Blue Unknown Burnie Burns, Jason Salda...
# 6230    Maron Unknown Marc Maron, Judd Hirsch, Josh Br...
# 6231    Little Baby Bum: Nursery Rhyme Friends Unknown...
# 6232    A Young Doctor's Notebook and Other Stories Un...
# 6233    Friends Unknown Jennifer Aniston, Courteney Co...
# Length: 6234, dtype: object

# %%
vectorize=TfidfVectorizer()

# %%
vectorize_feature=vectorize.fit_transform(combine_feature)

# %%
print(vectorize_feature)
# Out:
#   (0, 6163)	0.06530245161632797
#   (0, 19755)	0.04657312418693876
#   (0, 9212)	0.10187673348199125
#   (0, 5672)	0.10354026691718834
#   (0, 19002)	0.09646550453029838
#   (0, 14859)	0.16727505605476697
#   (0, 18410)	0.16654698017488467
#   (0, 8192)	0.24693377852393522
#   (0, 16867)	0.15106427771847095
#   (0, 29321)	0.21273181175194783
#   (0, 16487)	0.1106888432862278
#   (0, 12559)	0.1869468505299623
#   (0, 14119)	0.1365535161778982
#   (0, 4830)	0.15960607613158737
#   (0, 13849)	0.13932375699136845
#   (0, 12704)	0.1601690079818296
#   (0, 6102)	0.16193098882814366
#   (0, 7773)	0.368140758250741
#   (0, 4271)	0.1338211149096018
#   (0, 29498)	0.22801000967556215
#   (0, 1321)	0.1363150759943994
#   (0, 18134)	0.22801000967556215
#   (0, 796)	0.15318171271671133
#   (0, 17763)	0.2358640833753218
#   (0, 29216)	0.14270554588850703
#   :	:
#   (6232, 7997)	0.05497579484828799
#   (6232, 6861)	0.12255818694886499
#   (6232, 26595)	0.06865510902388836
# ...

# %%
Cosine_similarity=cosine_similarity(vectorize_feature)

# %%
Cosine_similarity.shape
# Out:
# (6234, 6234)

# %%
movie_name=input("Your favourite movie name:  ")
# Out:
# Your favourite movie name:  Norm of the North: King Sized Adventure

# %%
list_of_titles=df["title"].tolist()

# %%
list_of_titles
# Out:
# ['Norm of the North: King Sized Adventure',
#  'Jandino: Whatever it Takes',
#  'Transformers Prime',
#  'Transformers: Robots in Disguise',
#  '#realityhigh',
#  'Apaches',
#  'Automata',
#  'Fabrizio Copano: Solo pienso en mi',
#  'Fire Chasers',
#  'Good People',
#  'Joaquín Reyes: Una y no más',
#  'Kidnapping Mr. Heineken',
#  'Krish Trish and Baltiboy',
#  'Krish Trish and Baltiboy: Battle of Wits',
#  'Krish Trish and Baltiboy: Best Friends Forever',
#  'Krish Trish and Baltiboy: Comics of India',
#  'Krish Trish and Baltiboy: Oversmartness Never Pays',
#  'Krish Trish and Baltiboy: Part II',
#  'Krish Trish and Baltiboy: The Greatest Trick',
#  'Love',
#  'Manhattan Romance',
#  'Moonwalkers',
#  'Rolling Papers',
#  'Stonehearst Asylum',
#  'The Runner',
#  '6 Years',
#  'Castle of Stars',
#  'City of Joy',
#  'First and Last',
#  'Laddaland',
#  'Next Gen',
#  'Sierra Burgess Is A Loser',
#  'The Most Assassinated Woman in the World',
#  'Cézanne et moi',
# ...

# %%
find_close_match_movie_name=difflib.get_close_matches(movie_name,list_of_titles)

# %%
find_close_match_movie_name
# Out:
# ['Norm of the North: King Sized Adventure',
#  'Norm of the North: Keys to the Kingdom']

# %%
movie_index=df[df["title"]== 'Norm of the North: King Sized Adventure'].index[0]

# %%
smilarity_movie_name=list(enumerate(Cosine_similarity[movie_index]))

# %%
print(smilarity_movie_name)
# Out:
# [(0, 1.0000000000000002), (1, 0.0), (2, 0.009190490683500672), (3, 0.0), (4, 0.013302320385374964), (5, 0.0), (6, 0.023490260084310474), (7, 0.0), (8, 0.0), (9, 0.01636938320649601), (10, 0.0), (11, 0.010800589916458506), (12, 0.036489503284861696), (13, 0.03787821931171022), (14, 0.028281888302754608), (15, 0.04272218017004439), (16, 0.02927906592594845), (17, 0.03332395423102743), (18, 0.03417080948170586), (19, 0.003684219184245999), (20, 0.010067130182452727), (21, 0.015097043058547688), (22, 0.0), (23, 0.011637177901555391), (24, 0.008315731162816226), (25, 0.025324708058922767), (26, 0.012684764073664404), (27, 0.023666797154145925), (28, 0.0), (29, 0.004530911220165304), (30, 0.046061379972772785), (31, 0.03854648354689062), (32, 0.03419832925919754), (33, 0.004128544664806566), (34, 0.005471311139699912), (35, 0.0020644403184457527), (36, 0.014612497381573757), (37, 0.0066690585704414235), (38, 0.007737186657808475), (39, 0.005351047172583507), (40, 0.03474753775981227), (41,
# ...

# %%
sort_similarity_score=sorted(smilarity_movie_name,key=lambda x:x[1],reverse=True)

# %%
# Out:
# [(1780, 1.0),
#  (0, 0.6678195482818207),
#  (5901, 0.17054367650555696),
#  (980, 0.1683549387764086),
#  (739, 0.15389934472252495),
#  (1534, 0.14413911037037036),
#  (6162, 0.13050483645432165),
#  (1552, 0.1273714806648923),
#  (5767, 0.12382450658246072),
#  (427, 0.1225368471926226),
#  (3308, 0.12165538880568905),
#  (6144, 0.12136966486552084),
#  (3613, 0.1112422365461052),
#  (935, 0.10477520206797741),
#  (260, 0.10403640935718153),
#  (2296, 0.10279261425119669),
#  (832, 0.10128707799838849),
#  (5780, 0.10038950660055544),
#  (4024, 0.1000724507740106),
#  (4443, 0.0998381810464858),
#  (2735, 0.09928854172003555),
#  (4135, 0.09919833439766271),
#  (2010, 0.09666528231202437),
#  (4461, 0.09436888929308457),
#  (4864, 0.09286360125906126),
#  (4977, 0.09127860195204202),
#  (4023, 0.09121504561029295),
#  (4916, 0.09028782423033031),
#  (57, 0.08882834638661441),
#  (3364, 0.08787344728748062),
#  (1106, 0.08645273654475293),
#  (203, 0.08532498986270866),
# ...

# %%
j=1
for i in sort_similarity_score:

    index=i[0]
    movie_name=df[df.index==index]["title"].values[0]
    a.append(movie_name)
    if j<10:
        print(i,' ',movie_name)
        j+=1
# Out:
# (0, 1.0000000000000002)   Norm of the North: King Sized Adventure
# (1780, 0.6678195482818207)   Norm of the North: Keys to the Kingdom
# (6162, 0.19114800020492093)   Dinotrux
# (6144, 0.17776788473817146)   Dinotrux Supercharged
# (5767, 0.17456776175058708)   The Deep
# (5688, 0.15242594075519708)   Edgar Rice Burroughs' Tarzan and Jane
# (3286, 0.15142325160824227)   Mune: Guardian of the Moon
# (2302, 0.13816293470116617)   Hulk Vs.
# (930, 0.12962849900381254)   Barbie: The Princess & the Popstar
